# %%
from pprint import PrettyPrinter
pp = PrettyPrinter(indent=2)
import torchvision
voc2007train = torchvision.datasets.VOCSegmentation('./datasets/VOC2007', year='2007', image_set='train', download=True)
voc2007train
# Out:
# Using downloaded and verified file: ./datasets/VOC2007/VOCtrainval_06-Nov-2007.tar
# Dataset VOCSegmentation
#     Number of datapoints: 209
#     Root location: ./datasets/VOC2007

# %%
voc2007train[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=500x281 at 0x10DCE4C88>,
#  <PIL.PngImagePlugin.PngImageFile image mode=P size=500x281 at 0x128CDD7B8>)

# %%
voc2007train[0][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x281 at 0x10DCEA6D8>

# %%
voc2007train[0][1]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=500x281 at 0x128D0CB00>

# %%
voc2007train.extra_repr
# Out:
# <bound method VisionDataset.extra_repr of Dataset VOCSegmentation
#     Number of datapoints: 209
#     Root location: ./datasets/VOC2007>

# %%
voc2007train.filename
# Out:
# 'VOCtrainval_06-Nov-2007.tar'

# %%
voc2007train.image_set
# Out:
# 'train'

# %%
voc2007train.images[0]
# Out:
# './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/000032.jpg'

# %%
voc2007train.masks[0]
# Out:
# './datasets/VOC2007/VOCdevkit/VOC2007/SegmentationClass/000032.png'

# %%
voc2007train.md5
# Out:
# 'c52e279531787c972589f7e41ab4ae64'

# %%
voc2007train.mro
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-78d3fc770d9a> in <module>
# ----> 1 voc2007train.mro
#
# AttributeError: 'VOCSegmentation' object has no attribute 'mro'

# %%
voc2007train.root
# Out:
# './datasets/VOC2007'

# %%
voc2007train.target_transform

# %%
voc2007train.transform

# %%
voc2007train.transforms

# %%
voc2007train.url
# Out:
# 'http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar'

# %%
voc2007train.year
# Out:
# '2007'
