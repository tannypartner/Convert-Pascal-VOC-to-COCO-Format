# %%
from pprint import PrettyPrinter
pp = PrettyPrinter(indent=2)
import torchvision
voc2007train = torchvision.datasets.VOCDetection('./datasets/VOC2007', year='2007', image_set='train', download=True)
voc2007train
# Out:
# Using downloaded and verified file: ./datasets/VOC2007/VOCtrainval_06-Nov-2007.tar
# Dataset VOCDetection
#     Number of datapoints: 2501
#     Root location: ./datasets/VOC2007

# %%
pp.pprint(voc2007train[0])
# Out:
# ( <PIL.Image.Image image mode=RGB size=500x333 at 0x12D44B550>,
#   { 'annotation': { 'filename': '000012.jpg',
#                     'folder': 'VOC2007',
#                     'object': [ { 'bndbox': { 'xmax': '351',
#                                               'xmin': '156',
#                                               'ymax': '270',
#                                               'ymin': '97'},
#                                   'difficult': '0',
#                                   'name': 'car',
#                                   'pose': 'Rear',
#                                   'truncated': '0'}],
#                     'owner': {'flickrid': 'KevBow', 'name': '?'},
#                     'segmented': '0',
#                     'size': {'depth': '3', 'height': '333', 'width': '500'},
#                     'source': { 'annotation': 'PASCAL VOC2007',
#                                 'database': 'The VOC2007 Database',
# ...

# %%
voc2007train[0][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x333 at 0x12D33FC88>

# %%
voc2007train.annotations[0]
# Out:
# './datasets/VOC2007/VOCdevkit/VOC2007/Annotations/000012.xml'

# %%
voc2007train.filename
# Out:
# 'VOCtrainval_06-Nov-2007.tar'

# %%
voc2007train.transform

# %%
voc2007train.images
# Out:
# JPEGImages/002755.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002757.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002759.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002763.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002765.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002766.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002774.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002778.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002779.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002782.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002783.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002791.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002795.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002796.jpg',
#  './datasets/VOC2007/VOCdevkit/VOC2007/JPEGImages/002801.jpg',
# ...

# %%
voc2007train.md5
# Out:
# 'c52e279531787c972589f7e41ab4ae64'

# %%
voc2007train.mro
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-78d3fc770d9a> in <module>
# ----> 1 voc2007train.mro
#
# AttributeError: 'VOCDetection' object has no attribute 'mro'

# %%
voc2007train.parse_voc_xml
# Out:
# <bound method VOCDetection.parse_voc_xml of Dataset VOCDetection
#     Number of datapoints: 2501
#     Root location: ./datasets/VOC2007>

# %%
voc2007train.root
# Out:
# './datasets/VOC2007'

# %%
voc2007train.target_transform

# %%
voc2007train.transforms

# %%
voc2007train.url
# Out:
# 'http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar'

# %%
voc2007train.year
# Out:
# '2007'
